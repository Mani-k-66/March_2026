# %%
intitude="edukron"
course="datascience"

# %%
intitude.upper()
# Out:
# 'EDUKRON'

# %%
intitude.lower()
# Out:
# 'edukron'

# %%
name_length = len(intitude)
print(f"1. Length of '{intitude}': {name_length}")
# Out:
# 1. Length of 'edukron': 7

# %%
name_length = len(course)
print(f"1. Length of '{course}': {name_length}")
# Out:
# 1. Length of 'datascience': 11

# %%
empty_len = len("")
print(f"1. Length of empty string: {empty_len}")
# Out:
# 1. Length of empty string: 0

# %%
spaces = "   "
spaces_len = len(spaces)
print(f" Length of '{spaces}': {spaces_len}")
# Out:
#  Length of '   ': 3

# %%
intitude="edukro"

# %%
first_chr=intitude[0]
print(f"first charector of intitude is:{first_chr}")
# Out:
# first charector of intitude is:e

# %%
lost_chr=intitude[0]
print(f"lost charector of intitude is :{lost_chr}")
# Out:
# lost charector of intitude is :e

# %%
middel_chr=intitude[0]
print(f"middel charector of intitude is :{middel_chr}")
# Out:
# middel charector of intitude is :e

# %%
middel_chr=course[0:5]
print(f"middel  charactor of course is :{middel_chr}")
# Out:
# middel  charactor of course is :datas

# %%
last_6=course[-6:]
print(f"last 6 charactor of course is :{last_6}")
# Out:
# last 6 charactor of course is :cience

# %%
first_1=course[::]
print(f"first ::charector of course is :{first_1}")
# Out:
# first ::charector of course is :datascience

# %%
lower_course=course.lower()
print(f"lower of course is :{lower_course}")
# Out:
# lower of course is :datascience

# %%
name_length = len(intitude)
print(f" Length of '{intitude}': {name_length}")
# Out:
#  Length of 'edukron': 7

# %%
spaces = "   "
spaces_len = len(spaces)
print(f" Length of '{spaces}': {spaces_len}")
# Out:
#  Length of '   ': 3

# %%
char_str = "t"
char_len = len(char_str)
print(f" Length of '{char_str}': {char_len}")
# Out:
#  Length of 't': 1
