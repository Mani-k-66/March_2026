# %%
# Union
set1={1,1,1,2,3}
set2={1,2,3,4,5}
set3=set1.union(set2)

# %%
set3
# Out:
# {1, 2, 3, 4, 5}

# %%
set_a={"hello welcome"}
set_b={"hi WELCOME"}
set_c=set_a.union(set_b)

# %%
set_c
# Out:
# {'hello welcome', 'hi WELCOME'}

# %%
set_d={"hi WELCOME"}
set_c=set_a.union(set_d)

# %%
set_c
# Out:
# {'hello welcome', 'hi WELCOME'}

# %%
set_c=set_d.union(set_b)

# %%
set_c
# Out:
# {'hi WELCOME'}

# %%
all=set_a|set2|set1|set_c

# %%
all
# Out:
# {1, 2, 3, 4, 5, 'hello welcome', 'hi WELCOME'}

# %%
# Intersection
set1={1,1,1,2,3}
set2={1,2,3,4,5}
set3=set1.intersection(set2)

# %%
set3
# Out:
# {1, 2, 3}

# %%
set_a={"hello welcome"}
set_b={"hi WELCOME"}

# %%
set_c=set_a & set_b & set_d

# %%
set_c
# Out:
# set()

# %%
setc=set_b&set_d&set_a

# %%
setc
# Out:
# set()

# %%
set_c=set_a&set_b

# %%
set_c
# Out:
# set()

# %%
set3=set1&set2

# %%
set3
# Out:
# {1, 2, 3}

# %%
#Difference
set1={1,2,3,4,5,6}
set2={1,2,3,4,5}
set1-set2
# Out:
# {6}

# %%
set2
# Out:
# {1, 2, 3, 4, 5}

# %%
set1
# Out:
# {1, 2, 3}

# %%
set3=set1-set2

# %%
set3
# Out:
# set()

# %%
set1={1,2,3,4,6,7,8}

# %%
set3=set1-set2

# %%
set3
# Out:
# {6, 7, 8}

# %%
set_c=set_a.difference(set_c)

# %%
set_c
# Out:
# {'hello welcome'}

# %%
setc=set_b-set_c

# %%
setc
# Out:
# {'hi WELCOME'}

# %%
# Symmetric Difference
set1={1, 2, 3, 4,6,7,8}
set2={1,2,3,4,5}
set3=set1^set2

# %%
set3
# Out:
# {5, 6, 7, 8}

# %%
set4=set3^set2

# %%
set4
# Out:
# {1, 2, 3, 4, 6, 7, 8}

# %%
set2
# Out:
# {1, 2, 3, 4, 5}

# %%
# Sub set
set1=set2.issubset(set3)

# %%
set1
# Out:
# False

# %%
set1=set2.issubset(set4)

# %%
set1
# Out:
# False

# %%
set3.issubset(set2)
# Out:
# False

# %%
set1={1,2,3,4,5,6}

# %%
set1.issubset(set2)
# Out:
# False

# %%
set2.issubset(set1)
# Out:
# True

# %%
set1={1,2,3,4,5,6}
set2={1,2,3,4,6,5,7,8,1}

# %%
set1.issubset(set2)
# Out:
# True

# %%
# Supersetset
1={1,2,3,4,5,6}
set2={1,2,3,4,6,5,7,8,1}
set1.issuperset(set2)
# Out:
# False

# %%
set2.issuperset(set1)
# Out:
# True

# %%
# Disjoin
set1={1,2,3,4,5,6}
set2={1,2,3,4,6,5,7,8,1}
set1.isdisjoint(set2)
# Out:
# False

# %%
set2.isdisjoint(set1)
# Out:
# False

# %%
set3={1,2,3,5,6,7,8,9,6,1}
set4={1,2,3,4,5,0}

# %%
set2.isdisjoint(set3)
# Out:
# False

# %%
set3.isdisjoint(set1)
# Out:
# False

# %%
set4.isdisjoint(set3)
# Out:
# False

# %%
set6={123}
set7={1,2,3}
set6.isdisjoint(set7)
# Out:
# True
