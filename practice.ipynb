# %%
#Data_types
#int,float,string(str)

# %%
s1="hello"

# %%
type(s1)
# Out:
# str

# %%
num=10

# %%
type(num)
# Out:
# int

# %%
s1+" "+str(num)
# Out:
# 'hello 10'

# %%
s1 *3
# Out:
# 'hellohellohello'
