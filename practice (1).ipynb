# %%
# Task 1: Add Your Favorite Food
foods = ["pizza", "burger", "pasta"]
foods.append("biryani")

# %%
foods.append("roti")
print("foods")
# Out:
# foods

# %%
foods
# Out:
# ['pizza', 'burger', 'pasta', 'biryani', 'roti', 'roti']

# %%
# Add multiple items
colour=["red","blue"]

# %%
colour.extend(["green","yellow","white","black"])

# %%
print(colour)
# Out:
# ['red', 'blue', 'green', 'yellow', 'green', 'yellow', 'white', 'black']

# %%
# Insertat specific position
numbers=[1,2,4,5,6]
numbers.insert(2,3)

# %%
print(numbers)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# Remove an item
fruits=["apple","banana","mango","grapes"]
fruits.remove("mango")

# %%
print(fruits)
# Out:
# ['apple', 'banana', 'grapes']

# %%
# At remove last
items=["pen","book","eraser"]
items.remove("eraser")

# %%
items
# Out:
# ['pen', 'book']

# %%
items=["pen","book","eraser"]
items.pop()
# Out:
# 'eraser'

# %%
print(items)
# Out:
# ['pen', 'book']

# %%
# Find index
animals=["cat","dog","lion","tiger"]

# %%
animals.index("lion")
# Out:
# 2

# %%
print(animals)
# Out:
# ['cat', 'dog', 'lion', 'tiger']

# %%
# Count occurrences
nums=[1,2,2,3,2,4]
nums.count(2)
# Out:
# 3

# %%
# Sort the list
marks=[85,45,90,60]
marks.sort()

# %%
print(marks)
# Out:
# [45, 60, 85, 90]

# %%
marks.sort(reverse=True)

# %%
print(marks)
# Out:
# [90, 85, 60, 45]

# %%
# Reverse the list
letters=["a","b","c","d"]
letters.reverse()

# %%
print(letters)
# Out:
# ['d', 'c', 'b', 'a']

# %%
# Copy the list
original=[10,20,30]
original.copy()
# Out:
# [10, 20, 30]

# %%
print(original)
print(original.copy())
# Out:
# [10, 20, 30]
# [10, 20, 30]

# %%
duplicate=original.copy()

# %%
print(original)
print(duplicate)
# Out:
# [10, 20, 30]
# [10, 20, 30]

# %%
duplicate
# Out:
# [10, 20, 30]

# %%
# Clear the list
data=[1,2,3,4]
data.clear()

# %%
print(data)
# Out:
# []

# %%
# Extend a list
list1=[1,2]
list2=[3,4]
list1.extend(list2)

# %%
print(list2)
# Out:
# [3, 4]

# %%
list1
# Out:
# [1, 2, 3, 4]
